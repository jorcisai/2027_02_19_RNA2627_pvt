# %% [markdown]
# # 11 Transformer

# %% [markdown]
# [**Transformer (2017):**](https://en.wikipedia.org/wiki/Transformer_\(deep_learning\)) $\;$ Google's architecture for machine translation based on the **attention mechanism**

# %% [markdown]
# <div align="center"><img src="Figure_15.26.png" width="900"/></div>

# %% [markdown]
# [**3blue1brown:**](https://www.3blue1brown.com/) $\;$ See $\;$ [Transformers, the tech behind LLMs](https://www.3blue1brown.com/?v=gpt#video-section) $\;$ and $\;$ [Attention in transformers, step-by-step](https://www.3blue1brown.com/?v=attention#video-section)

# %% [markdown]
# <p style="page-break-after:always;"></p>
