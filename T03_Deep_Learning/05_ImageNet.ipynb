# %% [markdown]
# # 5 ImageNet

# %% [markdown]
# [**ImageNet:**](https://image-net.org/index.php) $\;$ dataset of $\,14\,197\,122\,$ images and $\,21\,841\,$ synsets; very popular since 2010
#
# [**ImageNet on Wikipedia:**](https://en.wikipedia.org/wiki/ImageNet#) $\;$ history, dataset, challenge and biases
#
# [**ImageNet en HF:**](https://huggingface.co/datasets?sort=downloads&search=imagenet) $\;$ ILSVRC/imagenet-1k, gmongaras/Imagenet21K, benjamin-paine/imagenet-1k-256x256, etc.
#
# [**ImageNet-1K:**](https://huggingface.co/datasets/ILSVRC/imagenet-1k) $\;$ subset of 1.4M images and 1000 classes
#
# **Standard partition:** $\;$ $1\,281\,167\,$ for training, $\,50\,000\,$ for validation y $\,100\,000\,$ for testing (with class label -1)

# %%
import numpy as np; import datasets
ds = datasets.load_dataset("ILSVRC/imagenet-1k"); ds
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['image', 'label'],
#         num_rows: 1281167
#     })
#     validation: Dataset({
#         features: ['image', 'label'],
#         num_rows: 50000
#     })
#     test: Dataset({
#         features: ['image', 'label'],
#         num_rows: 100000
#     })
# })

# %% [markdown]
# <p style="page-break-after:always;"></p>
