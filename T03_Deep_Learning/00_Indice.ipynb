# %% [markdown]
# # T03 Deep learning

# %% [markdown]
# **Index**
#
# 1. Introduction
# 2. LeNet
# 3. Convolutional Layers
# 4. Pooling
# 5. ImageNet
# 6. AlexNet
# 7. Dropout
# 8. Inception
# 9. ResNet
# 10. Normalization Layers
# 11. Transformer
# 12. Vision Transformer

# %% [markdown]
# <p style="page-break-after:always;"></p>
