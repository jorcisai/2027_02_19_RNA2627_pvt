# %% [markdown]
# # 6 AlexNet

# %% [markdown]
# [**AlexNet (2012):**](https://en.wikipedia.org/wiki/AlexNet) $\;$ CNN for ImageNet that started the deep learning revolution at [ILSVRC 2012](https://image-net.org/challenges/LSVRC/2012/results.html)

# %% [markdown]
# <div align="center"><img src="LeNetAlexNet.png" width="700"/></div>

# %% [markdown]
# <p style="page-break-after:always;"></p>
