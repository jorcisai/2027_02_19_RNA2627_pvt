# %% [markdown]
# # 12 Vision Transformer

# %% [markdown]
# [**Vision Transformer (2020):**](https://en.wikipedia.org/wiki/Vision_transformer) $\;$ Transformer adaptation for vision that rivals CNNs

# %% [markdown]
# <div align="center"><img src="Figure_15.28.png" width="900"/></div>

# %% [markdown]
# **SOTA on ImageNet:** $\;$ see [Ross Wightman results files](https://github.com/huggingface/pytorch-image-models/tree/main/results)

# %% [markdown]
# <p style="page-break-after:always;"></p>
