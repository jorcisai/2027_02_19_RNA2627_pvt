# %% [markdown]
# # T02 Backprop algorithm

# %% [markdown]
# **Index**
#
# 1. Introduction<br>
# 2. Backprop algorithm<br>
# 3. Example of regression with a data sample<br>
# 4. Example of regression with a batch<br>
# 5. Example of XOR with softmax output<br>
# 6. Exercise: XOR with sigmoid output<br>

# %% [markdown]
# <p style="page-break-after:always;"></p>
