# %% [markdown]
# # 1 Introduction

# %% [markdown]
# **Objective:** $\quad$ introduce the Backprop algorithm for training multilayer perceptrons with usage examples

# %% [markdown]
# **Backprop:** $\quad$ First we will look at the generic Backprop algorithm for finding the gradient of a model

# %% [markdown]
# **Example with a regression network:** $\quad$ Gradient calculation and parameter update
#
# * Starting from a data point
#
# * Generalizing data to a batch

# %% [markdown]
# **XOR:** $\quad$ Gradient calculation and parameter update
#
# * Example: Network with a hidden layer of two ReLUs and softmax output
#
# * Exercise: Analogous to the example, but with sigmoid output instead of softmax

# %% [markdown]
# <p style="page-break-after:always;"></p>
