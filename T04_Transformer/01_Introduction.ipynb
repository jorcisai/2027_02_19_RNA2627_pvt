# %% [markdown]
# # 1 Introduction

# %% [markdown]
# **Transformer (vanilla):** $\;$ SOTA architecture introduced in the 2017 article [Attention Is All You Need](https://arxiv.org/abs/1706.03762)

# %% [markdown]
# **Intro videos by 3blue1brown:**
# * [Transformers, the tech behind LLMs](https://www.3blue1brown.com/?v=gpt#video-section)
# * [Attention in transformers, step-by-step](https://www.3blue1brown.com/?v=attention#video-section)
# * [How might LLMs store facts](https://www.3blue1brown.com/?v=mlp#video-section)

# %% [markdown]
# [**Annotated Transformer 2025 (AT25):**](https://github.com/yflyzhang/AnnotatedTransformer) $\;$ implementation designed as an educational resource to introduce Transformer
# 1. Part 1: Model Architecture
# 2. Part 2: Preparation for Training
# 3. Part 3: Toy Training Example
# 4. Part 4: A Real World Example
# 5. Part 5: Attention Visualization

# %% [markdown]
# **Objective:** $\;$ To introduce the Transformer architecture based on AT25, mainly the first part

# %% [markdown]
# <p style="page-break-after:always;"></p>
