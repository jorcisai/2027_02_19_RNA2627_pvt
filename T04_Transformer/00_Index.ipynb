# %% [markdown]
# # T4 Transformer

# %% [markdown]
# **Index**
#
# 1. Introduction
# 2. Architecture
# 3. Neural Machine Translation
# 4. Positional Encoding
# 5. Dropout
# 6. LayerNorm
# 7. Scaled Dot-Product Attention
# 8. Multi-head Attention
# 9. Residual Connections
# 10. Position-wise Feed-Forward Networks
# 11. Encoder
# 12. Decoder
# 13. Transformer
# 14. Training
# 15. Activation Functions
# 16. Attention Mechanisms
# 17. RMS Layer Normalization
# 18. Mixture of Experts
# 19. Rotatory Positional Encoding

# %% [markdown]
# <p style="page-break-after:always;"></p>
