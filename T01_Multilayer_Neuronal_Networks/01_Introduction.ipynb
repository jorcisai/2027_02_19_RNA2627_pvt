# %% [markdown]
# # 1 Introduction

# %% [markdown]
# **Objective:** $\;$ To introduce multilayer perceptrons with usage examples

# %% [markdown]
# **The XOR problem:** $\quad$ simple problem that cannot be solved with a classical linear model (Perceptron)

# %% [markdown]
# **Multilayer Perceptrons:** $\quad$ generalization of the classic Perceptron that forms the basis of current networks

# %% [markdown]
# **TensorFlow Playground:** $\quad$ web tool for playing with simple networks applied to 2D data

# %% [markdown]
# **Example of MLP for classification:** $\quad$ MNIST task

# %% [markdown]
# **Example of MLP for regression:** $\quad$ auto-mpg task

# %% [markdown]
# **Final considerations:** $\;$ background, importance of depth, etc.

# %% [markdown]
# <p style="page-break-after:always;"></p>
