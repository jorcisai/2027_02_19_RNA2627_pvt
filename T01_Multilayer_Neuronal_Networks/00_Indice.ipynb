# %% [markdown]
# # T8 Perceptrones multicapa

# %% [markdown]
# **Índice**
#
# 1. Introducción<br>
# 2. Perceptrón: el problema XOR<br>
# 3. Perceptrones multicapa<br>
# 4. Funciones de activación<br>
# 5. TensorFlow Playground<br>
# 6. Ejemplo de MLP para clasificación<br>
# 7. Ejemplo de MLP para regresión<br>
# 8. Consideraciones finales

# %% [markdown]
# <p style="page-break-after:always;"></p>
