# %% [markdown]
# # T01 Multilayer Neural Networks

# %% [markdown]
# **Table of Contents**
#
# 1. Introduction<br>
# 2. Perceptron: The XOR Problem<br>
# 3. Multilayer Perceptrons<br>
# 4. Activation Functions<br>
# 5. TensorFlow Playground<br>
# 6. Example of an MLP for Classification<br>
# 7. Example of an MLP for Regression<br>
# 8. Final Considerations

# %% [markdown]
# <p style="page-break-after:always;"></p>
