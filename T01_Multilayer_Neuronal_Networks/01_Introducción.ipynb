# %% [markdown]
# # 1 Introducción

# %% [markdown]
# **Objetivo:** $\;$ introducir los perceptrones multicapa con ejemplos de uso

# %% [markdown]
# **El problema XOR:** $\quad$ problema simple que no puede resolverse con un modelo lineal clásico (Perceptrón)

# %% [markdown]
# **Perceptrones multicapa:** $\quad$ generalización del Perceptrón clásico que constituye la base de las redes actuales

# %% [markdown]
# **TensorFlow Playground:** $\quad$ herramienta web para jugar con redes sencillas aplicadas a datos 2d

# %% [markdown]
# **Ejemplo de MLP para clasificación:** $\quad$ tarea MNIST

# %% [markdown]
# **Ejemplo de MLP para regresión:** $\quad$ tarea auto-mpg

# %% [markdown]
# **Consideraciones finales:** $\;$ antecedentes, importancia de la profundidad, etc.

# %% [markdown]
# <p style="page-break-after:always;"></p>
